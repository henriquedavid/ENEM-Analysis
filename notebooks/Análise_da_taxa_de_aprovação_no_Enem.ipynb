# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-69033347-351e-4724-9f93-4eafb0a0b14c" name="files[]" multiple disabled />
#      <output id="result-69033347-351e-4724-9f93-4eafb0a0b14c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving geojs-24-mun.json to geojs-24-mun.json
# User uploaded file "geojs-24-mun.json" with length 232763 bytes

# %%
# !pip install xlrd
# Out:
# Collecting xlrd
#   Downloading https://files.pythonhosted.org/packages/07/e6/e95c4eec6221bfd8528bcc4ea252a850bffcc4be88ebc367e23a1a84b0bb/xlrd-1.1.0-py2.py3-none-any.whl (108kB)
#     100% |████████████████████████████████| 112kB 2.7MB/s
# Installing collected packages: xlrd
# Successfully installed xlrd-1.1.0

# %%
import pandas as pd 

escola = pd.read_excel('PLANILHA_ENEM_ESCOLA_2014.xlsx', skiprows=[0])
rn_state = escola[escola['SIGLA DA UF'] == 'RN']
rn_state.head()
# Out:
#       CÓDIGO DA ENTIDADE                         NOME DA ENTIDADE SIGLA DA UF  \
# 9829            24034410            ESC EST DR JOSE G DE MEDEIROS          RN
# 9830            24034428  ESC EST PROFA IRACEMA BRANDAO DE ARAUJO          RN
# 9831            24081566           ESCOLA ESTADUAL PADRE IBIAPINA          RN
# 9832            24009296         COMPLEXO EDUCACIONAL SANTO ANDRE          RN
# 9833            24009318       EDUCANDARIO NOSSA SRA DAS VITORIAS          RN
#
#      MUNICÍPIO DEPENDÊNCIA ADMINISTRATIVA LOCALIZAÇÃO  \
# 9829     ACARI                   Estadual      Urbana
# 9830     ACARI                   Estadual      Urbana
# 9831       ACU                   Estadual      Urbana
# 9832       ACU                    Privada      Urbana
# 9833       ACU                    Privada      Urbana
#
#       NÚMERO DE ALUNOS NO CENSO     PORTE DA ESCOLA  \
# 9829                         43   De 31 a 60 alunos
# 9830                         53   De 31 a 60 alunos
# 9831                        266  Mais que 90 alunos
# 9832                         35   De 31 a 60 alunos
# 9833                         62   De 61 a 90 alunos
#
#       NÚMERO DE PARTICIPANTES NO ENEM  TAXA DE PARTICPAÇÃO  \
# 9829                               37            86.046512
# 9830                               41            77.358491
# 9831                              169            63.533835
# 9832                               31            88.571429
# 9833                               53            85.483871
#
#                 ...              TAXA DE APROVAÇÃO TAXA DE REPROVAÇÃO  \
# 9829            ...                           87.9                4.9
# 9830            ...                           70.5               14.3
# 9831            ...                           79.1               18.6
# 9832            ...                           91.7                7.4
# 9833            ...                           93.4                6.3
#
#      TAXA DE ABANDONO MÉDIA DOS 30 MELHORES ALUNOS DA ESCOLA       MÉDIA  \
# 9829              7.2                             523.896667  500.786486
# 9830             15.2                             498.913333  470.887805
# 9831              2.3                             557.503333  471.866864
# 9832              0.9                             531.983333  528.038710
# 9833              0.3                             567.156667  526.533962
#
#      Percentual alunos NÍVEL 1 Percentual alunos NÍVEL 2  \
# 9829                 16.216216                 59.459459
# 9830                 34.146341                 60.975610
# 9831                 37.869822                 48.520710
# 9832                 16.129032                 41.935484
# 9833                  9.433962                 50.943396
#
#      Percentual alunos NÍVEL 3  Percentual alunos NÍVEL 4  \
# 9829                 24.324324                   0.000000
# 9830                  4.878049                   0.000000
# 9831                 13.609467                   0.000000
# 9832                 41.935484                   0.000000
# 9833                 37.735849                   1.886792
#
#       Percentual alunos NÍVEL 5
# 9829                        0.0
# 9830                        0.0
# 9831                        0.0
# 9832                        0.0
# 9833                        0.0
#
# [5 rows x 25 columns]

# %%
escolas_rn = {}
numero_escola = {}
cidade = []
for _, row in rn_state.iterrows():
    if row['MUNICÍPIO'] in escolas_rn:
        escolas_rn[row['MUNICÍPIO']] += row['MÉDIA']
        numero_escola[row['MUNICÍPIO']] += 1
    else:
        escolas_rn[row['MUNICÍPIO']] = row['MÉDIA']
        numero_escola[row['MUNICÍPIO']] = 1
        cidade.append(row["MUNICÍPIO"])

for r in cidade:
    escolas_rn[r] = escolas_rn[r]/numero_escola[r]
print(escolas_rn)
# Out:
# {'ACARI': 485.83714568226765, 'ACU': 514.1610744379144, 'AGUA NOVA': 452.17368421052635, 'ALEXANDRIA': 483.63571428571424, 'ALMINO AFONSO': 466.43913043478256, 'ANGICOS': 465.1925373134328, 'ANTONIO MARTINS': 467.4651162790698, 'APODI': 488.85546435754804, 'AREIA BRANCA': 498.85073108709474, 'BAIA FORMOSA': 470.6759259259259, 'BARAUNA': 493.9636111111111, 'BARCELONA': 464.10833333333335, 'BENTO FERNANDES': 462.2421052631579, 'BOM JESUS': 471.858, 'BREJINHO': 469.1530120481928, 'CAICARA DO RIO DO VENTO': 443.23333333333335, 'CAICO': 517.2047231627113, 'CAMPO REDONDO': 444.4517857142857, 'CANGUARETAMA': 471.7373831775701, 'CARAUBAS': 472.6232220160792, 'CARNAUBA DOS DANTAS': 467.54347826086956, 'CEARA-MIRIM': 490.85263157894747, 'CERRO CORA': 480.27818181818185, 'CORONEL EZEQUIEL': 474.7034482758621, 'CORONEL JOAO PESSOA': 449.23214285714283, 'CRUZETA': 494.4599999999999, 'CURRAIS NOVOS': 524.5957003693266, 'DOUTOR SEVERIANO': 481.41886792452834, 'ENCANTO': 487.3741935483871, 'EQUADOR': 476.30270270270273, 'ESPIRITO SANTO': 476.92045454545456, 'EXTREMOZ': 483.928947368421, 'FELIPE GUERRA': 445.0786885245902, 'FRANCISCO DANTAS': 475.788, 'FRUTUOSO GOMES': 463.9655172413793, 'GOIANINHA': 558.3375, 'GOVERNADOR DIX-SEPT ROSADO': 472.89861111111117, 'GROSSOS': 481.5274509803922, 'IPANGUACU': 562.2838383838383, 'IPUEIRA': 476.4130434782609, 'ITAJA': 449.1723404255319, 'ITAU': 477.9767441860465, 'JACANA': 491.8448275862069, 'JARDIM DE ANGICOS': 477.25454545454545, 'JARDIM DE PIRANHA
#   Downloading https://files.pythonhosted.org/packages/38/b6/b53f19062afd49bb5abd049aeed36f13bf8d57ef8f3fa07a5203531a0252/Shapely-1.6.4.post2-cp36-cp36m-manylinux1_x86_64.whl (1.5MB)
#     100% |████████████████████████████████| 1.5MB 14.3MB/s
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/55/e2/7e523df8558b7f4b2ab4c62014fd378ccecce3fdc14c9928b272a88ae4cc/folium-0.7.0-py3-none-any.whl (85kB)
#     100% |████████████████████████████████| 92kB 25.8MB/s
# Collecting unidecode
#   Downloading https://files.pythonhosted.org/packages/31/39/53096f9217b057cb049fe872b7fc7ce799a1a89b76cf917d9639e7a558b5/Unidecode-1.0.23-py2.py3-none-any.whl (237kB)
#     100% |████████████████████████████████| 245kB 26.4MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from folium) (1.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from folium) (1.14.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from folium) (2.18.4)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from folium) (2.10)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2018.10.15)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (1.22)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->folium) (1.1.0)
# Installing collected packages: shapely, branca, folium, unidecode
# Successfully installed branca-0.3.1 folium-0.7.0 shapely-1.6.4.post2 unidecode-1.0.23

# %%
import os
import folium
import json
from branca.colormap import linear
import numpy as np
from numpy import random
import unidecode

# %%
geo_json_data = json.load(open('geojs-24-mun.json',encoding='latin-1'))

# %%
colormap = linear.RdPu_03.scale(
    df.media.min(),
    df.media.max())

# %%
for i in geo_json_data['features']:
  if not i['properties']['name'].upper() in escolas_rn:
    escolas_rn[i['properties']['name'].upper()] = 0
escolas_rn["ARES"] = 0

# %%
lat = [-5.663889, -6.4636721, -6.3794156, -5.6455161, -6.2420251, -5.5444205, -5.5343439, -5.6931431,-5.1444515,-5.1951504,-5.8350506, -6.4598912, -6.6916059, -5.9225221, -6.1027702, -6.2309344, -5.7747709, -5.9343692]
lon = [-37.798889, -37.104435, -35.1322001, -35.4419311, -36.5124361, -36.871496, -35.8218385,-36.2146079,-36.5261654, -37.3766595,-35.2069457, -35.510892, -36.6696983, -35.2461203, -38.2283202, -36.0313754, -35.3945459, -35.829152]
name = ['Apodi', 'Caicó', 'Canguaretama', 'Ceará Mirim', 'Currais Novos', 'Ipanguaçu', 'João Camara', 'Lajes', 'Macau', 'Mossoró', 'Natal', 'Nova Cruz', 'Parelhas', 'Parnamirim', 'Pau dos ferros', 'Santa Cruz', 'São Gonçalo do Amarante', 'São Paulo do Potengi']

# %%
m = folium.Map(
    location=[-5.66556, -36.60111],
    zoom_start=8,
    tiles='Stamen Terrain'
)

folium.GeoJson(
    geo_json_data,
    name='Média de aprovação nas cidades do RN',
    style_function=lambda feature: {
        'fillColor': colormap(escolas_rn[unidecode.unidecode(feature['properties']['name'].upper())]),
        'color': 'black',
        'weight': 1,
        'dashArray': '5, 5',
        'fillOpacity': 0.9,
    }
).add_to(m)


for i in range(18):
  folium.Marker(location=[lat[i], lon[i]], popup=name[i]).add_to(m)


colormap.caption = 'Taxa de aprovação no ENEM nas cidades do RN'
colormap.add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
